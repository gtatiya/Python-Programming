# %% [markdown]
# # %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

#figure one
fig, axes = plt.subplots()
axes.plot(range(10))

#figure two
x = np.arange(0, 2 * np.pi)
fig, ((a,b),(c,d)) = plt.subplots(2,2)

a.plot(x, np.sin(x))
b.plot(x, np.cos(x))
c.plot(x, np.tan(x))
d.plot(x, np.tanh(x))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.show() # turn off %matplotlib notebook and use this
plt.close() # close to have multiple interactive plot
